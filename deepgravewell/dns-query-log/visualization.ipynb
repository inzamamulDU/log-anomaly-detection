# %%
import pandas as pd
import re
fd_linux = pd.read_csv("result/messages_structured.csv")

# %%
# append the timestamps to the log message
month_list, day_list, time_list = [], [], []
for i in range(len(fd_linux['Time'])):
    #print(fd_linux['Time'][i])
    time_list.append(re.split(':|\\.', fd_linux['Time'][i]))
for j in range(len(fd_linux['Date'])):
    day_list.append(int(fd_linux['Date'][j]))

# %%
time_list
# Out:
# [['00', '50', '05', '748'],
#  ['00', '50', '06', '250'],
#  ['00', '50', '06', '251'],
#  ['00', '50', '08', '735'],
#  ['00', '50', '08', '736'],
#  ['00', '50', '08', '739'],
#  ['00', '50', '08', '740'],
#  ['00', '50', '08', '740'],
#  ['00', '50', '08', '741'],
#  ['00', '50', '08', '741'],
#  ['00', '50', '08', '741'],
#  ['00', '50', '08', '742'],
#  ['00', '50', '08', '742'],
#  ['00', '50', '08', '743'],
#  ['00', '50', '13', '144'],
#  ['00', '50', '13', '647'],
#  ['00', '50', '13', '647'],
#  ['00', '50', '13', '648'],
#  ['00', '50', '13', '648'],
#  ['00', '50', '13', '649'],
#  ['00', '50', '13', '650'],
#  ['00', '50', '13', '650'],
#  ['00', '50', '13', '650'],
#  ['00', '50', '13', '651'],
#  ['00', '50', '13', '651'],
#  ['00', '50', '13', '652'],
#  ['00', '50', '13', '652'],
#  ['00', '50', '13', '653'],
#  ['00', '50', '16', '148'],
#  ['00', '50', '16', '650'],
#  ['00', '50', '16', '652'],
#  ['00', '50', '16', '654'],
#  ['00', '50', '16', '655'],
# ...
